# %%
import numpy as np
from matplotlib import pyplot as plt
from opt_test_functions import OptTestFunction

# %%
myTestFunction = OptTestFunction(function="Michalewicz", noise=False, noise_stddev=1, lower_limit=0, upper_limit=1)
x = np.random.random((6,3000)) # 6 dimensions, 3000 examples
y = myTestFunction.get(x)


for n in np.arange(x.shape[0]):
    fig, ax = plt.subplots(figsize=(14,5))
    plt.scatter(x[n,:],y) # Plot y against the nth dimension
    plt.show()
    plt.close()
